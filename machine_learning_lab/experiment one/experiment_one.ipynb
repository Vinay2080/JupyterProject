# %%
import numpy as np

# %%
import pandas as pd
from pandas import DataFrame

df: DataFrame = pd.read_csv('data_science_job - data_science_job.csv')
df_raw = df.copy()

# %%
df.shape
# Out:
# (19158, 13)

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.tail()
# Out:
#        enrollee_id      city  city_development_index gender  \
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline  experience company_size company_type  training_hours  \
# 19153       Humanities        14.0          NaN          NaN            42.0
# ...

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index    experience  training_hours  \
# count  19158.000000            18679.000000  19093.000000    18392.000000
# mean   16875.358179                0.828951      9.928036       65.185787
# std     9616.292592                0.123334      6.505268       59.885626
# min        1.000000                0.448000      0.000000        1.000000
# 25%     8554.250000                0.740000      4.000000       23.000000
# 50%    16982.500000                0.903000      9.000000       47.000000
# 75%    25169.750000                0.920000     16.000000       88.000000
# max    33380.000000                0.949000     20.000000      336.000000
#
#              target
# count  19158.000000
# mean       0.249348
# std        0.432647
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  int64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.9+ MB

# %%
df.isnull()
# Out:
#        enrollee_id   city  city_development_index  gender  \
# 0            False  False                   False   False
# 1            False  False                   False   False
# 2            False  False                   False    True
# 3            False  False                   False    True
# 4            False  False                   False   False
# ...            ...    ...                     ...     ...
# 19153        False  False                   False   False
# 19154        False  False                   False   False
# 19155        False  False                   False   False
# 19156        False  False                   False   False
# 19157        False  False                   False    True
#
#        relevent_experience  enrolled_university  education_level  \
# 0                    False                False            False
# 1                    False                False            False
# 2                    False                False            False
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df[100:200]
# Out:
#      enrollee_id      city  city_development_index  gender  \
# 100         6172   city_11                   0.550    Male
# 101        14672  city_173                   0.878     NaN
# 102        18257  city_103                   0.920  Female
# 103        24493  city_103                   0.920     NaN
# 104         1180   city_16                   0.910    Male
# ..           ...       ...                     ...     ...
# 195         9890  city_103                   0.920    Male
# 196        32683  city_160                   0.920    Male
# 197        27104   city_36                   0.893    Male
# 198         7731   city_65                   0.802    Male
# 199        31943   city_71                   0.884    Male
#
#          relevent_experience enrolled_university education_level  \
# 100  Has relevent experience       no_enrollment        Graduate
# 101   No relevent experience       no_enrollment         Masters
# ...

# %%
df1 = df[100:200]

# %%
df1
# Out:
#      enrollee_id      city  city_development_index  gender  \
# 100         6172   city_11                   0.550    Male
# 101        14672  city_173                   0.878     NaN
# 102        18257  city_103                   0.920  Female
# 103        24493  city_103                   0.920     NaN
# 104         1180   city_16                   0.910    Male
# ..           ...       ...                     ...     ...
# 195         9890  city_103                   0.920    Male
# 196        32683  city_160                   0.920    Male
# 197        27104   city_36                   0.893    Male
# 198         7731   city_65                   0.802    Male
# 199        31943   city_71                   0.884    Male
#
#          relevent_experience enrolled_university education_level  \
# 100  Has relevent experience       no_enrollment        Graduate
# 101   No relevent experience       no_enrollment         Masters
# ...

# %% [markdown]
# ## Creating Dataset

# %%
country = ['India', 'France', 'Germany', 'France', 'Germany', 'India', 'Germany', 'France', 'India', 'France']

# %%
len(country)
# Out:
# 10

# %%
age = [22, 29, 35, 26, 41, 24, 38, 31, 27, 34]

salary = [50000, 70000, 85000, 65000, 90000, 52000, 88000, 72000, 58000, 75000]

experience = [0, 5, 10, 3, 15, 1, 12, 7, 2, 8]

# %%
len(age)
# Out:
# 10

# %%
len(salary)
# Out:
# 10

# %%
list_example = pd.DataFrame({
    'Country': country,
    'Age': age,
    'Salary': salary,
    'Experience': experience
})

# %%
list_example
# Out:
#    Country  Age  Salary  Experience
# 0    India   22   50000           0
# 1   France   29   70000           5
# 2  Germany   35   85000          10
# 3   France   26   65000           3
# 4  Germany   41   90000          15
# 5    India   24   52000           1
# 6  Germany   38   88000          12
# 7   France   31   72000           7
# 8    India   27   58000           2
# 9   France   34   75000           8

# %%
df_raw
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df_raw[df_raw['gender'] == 'Male']
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 4              666  city_162                   0.767   Male
# 6            28806  city_160                   0.920   Male
# 7              402   city_46                   0.762   Male
# ...            ...       ...                     ...    ...
# 19151        11385  city_149                   0.689   Male
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
max(df['experience'])
# Out:
# 20.0

# %%
df_drop = df.dropna(axis=0)

# %%
df_drop.shape
# Out:
# (8434, 13)

# %%
df.value_counts()
# Out:
# enrollee_id  city      city_development_index  gender  relevent_experience      enrolled_university  education_level  major_discipline  experience  company_size  company_type    training_hours  target
# 2            city_103  0.920                   Male    No relevent experience   no_enrollment        Phd              STEM              15.0        10000+        NGO             128.0           1         1
# 4            city_103  0.920                   Male    No relevent experience   no_enrollment        Masters          STEM              9.0         50-99         Public Sector   13.0            0         1
# 8            city_103  0.920                   Female  No relevent experience   no_enrollment        Graduate         Humanities        13.0        100-500       Funded Startup  12.0            0         1
# ...

# %%
df.value_counts(['gender', 'city'])
# Out:
# gender  city
# Male    city_103    3099
#         city_21     1562
#         city_16     1146
#         city_114     992
#         city_160     609
#                     ...
# Other   city_80        1
#         city_84        1
#         city_90        1
#         city_91        1
#         city_99        1
# Name: count, Length: 255, dtype: int64

# %%
list_example
# Out:
#    Country  Age  Salary  Experience
# 0    India   22   50000           0
# 1   France   29   70000           5
# 2  Germany   35   85000          10
# 3   France   26   65000           3
# 4  Germany   41   90000          15
# 5    India   24   52000           1
# 6  Germany   38   88000          12
# 7   France   31   72000           7
# 8    India   27   58000           2
# 9   France   34   75000           8

# %%
list_example.loc[3, 'Age'] = np.nan

# %%
list_example.loc[6, 'Salary'] = np.nan

# %%
list_example
# Out:
#    Country   Age   Salary  Experience
# 0    India  22.0  50000.0           0
# 1   France  29.0  70000.0           5
# 2  Germany  35.0  85000.0          10
# 3   France   NaN  65000.0           3
# 4  Germany  41.0  90000.0          15
# 5    India  24.0  52000.0           1
# 6  Germany  38.0      NaN          12
# 7   France  31.0  72000.0           7
# 8    India  27.0  58000.0           2
# 9   France  34.0  75000.0           8

# %%
list_example.loc[list_example['Age'] == 41, 'Age'] = np.nan

# %%
list_example
# Out:
#    Country   Age   Salary  Experience
# 0    India  22.0  50000.0           0
# 1   France  29.0  70000.0           5
# 2  Germany  35.0  85000.0          10
# 3   France   NaN  65000.0           3
# 4  Germany   NaN  90000.0          15
# 5    India  24.0  52000.0           1
# 6  Germany  38.0      NaN          12
# 7   France  31.0  72000.0           7
# 8    India  27.0  58000.0           2
# 9   France  34.0  75000.0           8

# %%
list_example.loc[4, 'Age'] = 50

# %%
list_example
# Out:
#    Country   Age   Salary  Experience
# 0    India  22.0  50000.0           0
# 1   France  29.0  70000.0           5
# 2  Germany  35.0  85000.0          10
# 3   France   NaN  65000.0           3
# 4  Germany  50.0  90000.0          15
# 5    India  24.0  52000.0           1
# 6  Germany  38.0      NaN          12
# 7   France  31.0  72000.0           7
# 8    India  27.0  58000.0           2
# 9   France  34.0  75000.0           8

# %%
list_example.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     10 non-null     object
#  1   Age         9 non-null      float64
#  2   Salary      9 non-null      float64
#  3   Experience  10 non-null     int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
purchase = ['No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes']

# %%
df_purchase = pd.DataFrame(purchase, columns=['Purchase'])

# %%
df_purchase
# Out:
#   Purchase
# 0       No
# 1       No
# 2      Yes
# 3      Yes
# 4       No
# 5      Yes
# 6       No
# 7       No
# 8      Yes
# 9      Yes

# %%
list_example['Purchase'] = purchase

# %%
country_data = list_example

# %%
country_data.value_counts('Purchase')
# Out:
# Purchase
# No     5
# Yes    5
# Name: count, dtype: int64

# %%
country_data.value_counts()
# Out:
# Country  Age   Salary   Experience  Purchase
# France   29.0  70000.0  5           No          1
#          31.0  72000.0  7           No          1
#          34.0  75000.0  8           Yes         1
# Germany  35.0  85000.0  10          Yes         1
#          50.0  90000.0  15          No          1
# India    22.0  50000.0  0           No          1
#          24.0  52000.0  1           Yes         1
#          27.0  58000.0  2           Yes         1
# Name: count, dtype: int64

# %%
country_data[country_data['Purchase'] == 'Yes']
# Out:
#    Country   Age   Salary  Experience Purchase
# 2  Germany  35.0  85000.0          10      Yes
# 3   France   NaN  65000.0           3      Yes
# 5    India  24.0  52000.0           1      Yes
# 8    India  27.0  58000.0           2      Yes
# 9   France  34.0  75000.0           8      Yes

# %%
country_data
# Out:
#    Country   Age   Salary  Experience Purchase
# 0    India  22.0  50000.0           0       No
# 1   France  29.0  70000.0           5       No
# 2  Germany  35.0  85000.0          10      Yes
# 3   France   NaN  65000.0           3      Yes
# 4  Germany  50.0  90000.0          15       No
# 5    India  24.0  52000.0           1      Yes
# 6  Germany  38.0      NaN          12       No
# 7   France  31.0  72000.0           7       No
# 8    India  27.0  58000.0           2      Yes
# 9   France  34.0  75000.0           8      Yes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
country_data.head()
# Out:
#    Country   Age   Salary  Experience Purchase
# 0    India  22.0  50000.0           0       No
# 1   France  29.0  70000.0           5       No
# 2  Germany  35.0  85000.0          10      Yes
# 3   France   NaN  65000.0           3      Yes
# 4  Germany  50.0  90000.0          15       No

# %%
encoder = LabelEncoder()

# %%
empty_df = pd.DataFrame()

# %%
empty_df['Country'] = encoder.fit_transform(country_data['Country'])

# %%
empty_df
# Out:
#    Country
# 0        2
# 1        0
# 2        1
# 3        0
# 4        1
# 5        2
# 6        1
# 7        0
# 8        2
# 9        0

# %%
empty_df['Age'] = country_data['Age']

# %%
empty_df['Purchase'] = encoder.fit_transform(country_data['Purchase'])

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# %%
df_trans = pd.DataFrame(imputer.fit_transform(empty_df), columns=empty_df.columns)

# %%
df_trans
# Out:
#    Country        Age  Purchase
# 0      2.0  22.000000       0.0
# 1      0.0  29.000000       0.0
# 2      1.0  35.000000       1.0
# 3      0.0  32.222222       1.0
# 4      1.0  50.000000       0.0
# 5      2.0  24.000000       1.0
# 6      1.0  38.000000       0.0
# 7      0.0  31.000000       0.0
# 8      2.0  27.000000       1.0
# 9      0.0  34.000000       1.0

# %%
df_trans_copy = pd.DataFrame(df_trans)

# %%
df_trans_copy
# Out:
#      0          1    2
# 0  2.0  22.000000  0.0
# 1  0.0  29.000000  0.0
# 2  1.0  35.000000  1.0
# 3  0.0  32.222222  1.0
# 4  1.0  50.000000  0.0
# 5  2.0  24.000000  1.0
# 6  1.0  38.000000  0.0
# 7  0.0  31.000000  0.0
# 8  2.0  27.000000  1.0
# 9  0.0  34.000000  1.0
